# %%
import numpy as np
import requests
from bs4 import BeautifulSoup
import pandas as pd
import re

# %%
main_html = requests.get("https://sports.news.naver.com/kfootball/schedule/index.nhn?category=kleague2").text
main_soup = BeautifulSoup(main_html,"html.parser")
main_soup
# Out:
# <!DOCTYPE html>
#
# <html lang="ko">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="requiresActiveX=true" http-equiv="X-UA-Compatible"/>
# <meta content="width=1080px,maximum-scale=2.0,minimum-scale=0.4,user-scalable=yes" name="viewport"/>
# <meta content="https://imgsports.pstatic.net/images/mobile/common/NAVERsports.png" property="og:image">
# <meta content="일정/결과, 국내축구 : 네이버 스포츠" property="og:title">
# <meta content="스포츠의 시작과 끝!" property="og:description">
# <meta content="http://sports.news.naver.com/kfootball/schedule/index.nhn" property="og:url">
# <title>일정/결과, 국내축구 : 네이버 스포츠</title>
# <script src="https://ssl.pstatic.net/tveta/libs/assets/js/pc/main/min/pc.veta.core.min.js?201704051200" type="text/javascript"></script>
# <link href="https://ssl.pstatic.net/static.sports/resources/pc/2020/02/26/140019/css/generated/nsportsCss.css" rel="stylesheet" type="text/css"/>
# ...

# %%
main_soup.find("div", {"class": "schedule_info"})
# Out:
# <div class="schedule_info">
# 		네이버 스포츠에서 제공하는 일정, 결과, 기록 등의 데이터는 '제공처'의 사정에 따라 지연되거나 잘못 표시될 수 있습니다.<br/>
# 		네이버(주)는 그에 따른 스포츠 데이터의 정확성 및 신뢰성을 담보하지 않습니다. 궁금하신 사항은 <a class="link" href="https://help.naver.com/support/alias/contents2/sports/sports_5.naver" target="_blank">고객센터</a>를 통해서 문의해주시기 바랍니다.
# 	</div>
